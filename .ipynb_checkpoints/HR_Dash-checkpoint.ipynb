# %% [markdown]
# # *The purpose of this project is to showcase the measureables of our team, including certification scores, call coaching stats, and quality of new hire stats. All statistics are stored in a secure SQL database that I can not grant access to for testing the final project, but I utilized SQL to pull info from the database and created csv files from those queries. Utilizing Python to clean data and do a few visualizations here before doing visualizations in Tableau.*

# %% [markdown]
# ## **First step is to pull the data from SQL database.**

# %% [markdown]
# <p>Refer to SQL file: cert_pull_sql.sql, call_coach_pull.sql, QNH_pull.sql</p>

# %% [markdown]
# ## **Pulling in all needed dbs**

# %%
import pandas as pd 
import numpy as np
from faker import Faker
import matplotlib.pyplot as plt
import seaborn as sns
import tkinter as tk

# %% [markdown]
# # **Next step is to clean up the files.**
# <p> *For security purposes, the names in my file have already changed and been added to the original csv.* </p>

# %% [markdown]
# ## **Cleaning up Certification CSV:**

# %% [markdown]
# #### For the certification scores files, I need to first randomize the names in the first column for security purposes:

# %%
file_path = r"All Certs_Clean.csv"

# Read the CSV file into a DataFrame
cert = pd.read_csv(file_path)

# Randomize the names in the first column
fake = Faker()
cert['Employee'] = [fake.name() for _ in range(len(cert))]


# Display the DataFrame
print(cert.head())
# Out:
#              Employee                          Assessment Score Date Completed
# 0  Vincent Montgomery  RM12,Core Certification Assessment   87%     10/20/2023
# 1          Kelly Hart  RM12,Core Certification Assessment   59%     10/19/2023
# 2        Brian Murray  RM12,Core Certification Assessment  100%     10/17/2023
# 3  Michelle Carpenter  RM12,Core Certification Assessment   84%     10/13/2023
# 4        Chad Jenkins  RM12,Core Certification Assessment   91%     10/13/2023

# %% [markdown]
# ##### Next, I need to split the "Assessment" column into two individual columns:

# %%
# Split the 'Assessment' column based on a comma delimiter
cert[['Product', 'Assessment']] = cert['Assessment'].str.split(',', expand=True)

print(cert.head())
# Out:
#              Employee                     Assessment Score Date Completed  \
# 0  Vincent Montgomery  Core Certification Assessment   87%     10/20/2023
# 1          Kelly Hart  Core Certification Assessment   59%     10/19/2023
# 2        Brian Murray  Core Certification Assessment  100%     10/17/2023
# 3  Michelle Carpenter  Core Certification Assessment   84%     10/13/2023
# 4        Chad Jenkins  Core Certification Assessment   91%     10/13/2023
#
#   Product
# 0    RM12
# 1    RM12
# 2    RM12
# 3    RM12
# 4    RM12

# %% [markdown]
# ##### Adjusting the score column so I can convert it to an integer. Splitting based on % and then dropping that column:

# %%
# Split the 'Score' based on a % delimiter
cert[['Score', 'Drop']] = cert['Score'].str.split('%', expand=True)

# Drop the 'Drop' column created from the split
cert = cert.drop(columns=['Drop'])

print(cert.head())
# Out:
#              Employee                     Assessment Score Date Completed  \
# 0  Vincent Montgomery  Core Certification Assessment    87     10/20/2023
# 1          Kelly Hart  Core Certification Assessment    59     10/19/2023
# 2        Brian Murray  Core Certification Assessment   100     10/17/2023
# 3  Michelle Carpenter  Core Certification Assessment    84     10/13/2023
# 4        Chad Jenkins  Core Certification Assessment    91     10/13/2023
#
#   Product
# 0    RM12
# 1    RM12
# 2    RM12
# 3    RM12
# 4    RM12

# %% [markdown]
# ##### Converting score column to an integer and adding a new column Pass/Fail based on score >79:

# %%
# Convert the 'Score' to integers
cert['Score'] = cert['Score'].astype(int)

# Add a new column 'Pass/Fail' for scores over 79
cert['Pass/Fail'] = cert['Score'] > 79

print(cert.head())
# Out:
#              Employee                     Assessment  Score Date Completed  \
# 0  Vincent Montgomery  Core Certification Assessment     87     10/20/2023
# 1          Kelly Hart  Core Certification Assessment     59     10/19/2023
# 2        Brian Murray  Core Certification Assessment    100     10/17/2023
# 3  Michelle Carpenter  Core Certification Assessment     84     10/13/2023
# 4        Chad Jenkins  Core Certification Assessment     91     10/13/2023
#
#   Product  Pass/Fail
# 0    RM12       True
# 1    RM12      False
# 2    RM12       True
# 3    RM12       True
# 4    RM12       True

# %% [markdown]
# ##### Adding one last column of either 1 or 0 to make visualization easier in Tableau:

# %%
# Add a new column 'Sum' with 1 if 'Score' > 79 else 0
cert['Sum'] = cert['Score'].apply(lambda x: 1 if x > 79 else 0)
print(cert.head())
# Out:
#              Employee                     Assessment  Score Date Completed  \
# 0  Vincent Montgomery  Core Certification Assessment     87     10/20/2023
# 1          Kelly Hart  Core Certification Assessment     59     10/19/2023
# 2        Brian Murray  Core Certification Assessment    100     10/17/2023
# 3  Michelle Carpenter  Core Certification Assessment     84     10/13/2023
# 4        Chad Jenkins  Core Certification Assessment     91     10/13/2023
#
#   Product  Pass/Fail  Sum
# 0    RM12       True    1
# 1    RM12      False    0
# 2    RM12       True    1
# 3    RM12       True    1
# 4    RM12       True    1

# %% [markdown]
# ## **Cleaning up Call Coaching CSV:**

# %% [markdown]
# #### First, randomize the names:

# %%
file_path1 = r"call_coaching_2023_scores.csv"

# Read the CSV file into a DataFrame
call = pd.read_csv(file_path1)

# Randomize the names in the first column
fake = Faker()
call['Employee'] = [fake.name() for _ in range(len(call))]


# Display the DataFrame
print(call.head())
# Out:
#            Employee      Queue  Q1 - Call 1  Q1 - Call 2  Q2 - Call 1  \
# 0    Daniel Morales  Technical          NaN          NaN          NaN
# 1     Sherry Becker  Technical          NaN          NaN          NaN
# 2     Casey Leblanc  Technical         96.0         96.0         96.0
# 3  Robert Hernandez  Technical         98.0         96.0         96.0
# 4    Shelley Acosta  Technical        100.0         94.0        100.0
#
#    Q2 - Call 2  Q3 - Call 1  Q3 - Call 2  Q4 - Call 1  Q4 - Call 2 Scheduled
# 0          NaN          NaN          NaN          NaN          NaN       NaN
# 1          NaN          NaN          NaN          NaN          NaN       NaN
# 2        100.0          NaN          NaN          NaN          NaN       NaN
# 3         98.0        100.0        100.0          NaN          NaN       NaN
# 4        100.0          NaN          NaN          NaN          NaN       NaN

# %% [markdown]
# #### Next, find the nulls:

# %%
#Check for any nulls
call.isnull().any()
# Out:
# Employee       False
# Queue          False
# Q1 - Call 1     True
# Q1 - Call 2     True
# Q2 - Call 1     True
# Q2 - Call 2     True
# Q3 - Call 1     True
# Q3 - Call 2     True
# Q4 - Call 1     True
# Q4 - Call 2     True
# Scheduled       True
# dtype: bool

# %%
#Sum nulls in every column
call.isnull().sum()
# Out:
# Employee        0
# Queue           0
# Q1 - Call 1    70
# Q1 - Call 2    70
# Q2 - Call 1    73
# Q2 - Call 2    74
# Q3 - Call 1    73
# Q3 - Call 2    73
# Q4 - Call 1    99
# Q4 - Call 2    99
# Scheduled      69
# dtype: int64

# %% [markdown]
# #### Dropping rows where all scores are null:

# %%
#Dropping rows that are null across every column aside from column 1 and 2
call = call.dropna(subset=call.columns[2:], how='all')

print(call.head())
# Out:
#            Employee      Queue  Q1 - Call 1  Q1 - Call 2  Q2 - Call 1  \
# 2     Casey Leblanc  Technical         96.0         96.0         96.0
# 3  Robert Hernandez  Technical         98.0         96.0         96.0
# 4    Shelley Acosta  Technical        100.0         94.0        100.0
# 5       Joel Powers  Technical          NaN          NaN          NaN
# 6   Margaret Hughes  Technical          NaN          NaN         94.0
#
#    Q2 - Call 2  Q3 - Call 1  Q3 - Call 2  Q4 - Call 1  Q4 - Call 2 Scheduled
# 2        100.0          NaN          NaN          NaN          NaN       NaN
# 3         98.0        100.0        100.0          NaN          NaN       NaN
# 4        100.0          NaN          NaN          NaN          NaN       NaN
# 5          NaN         92.0         96.0          NaN          NaN       NaN
# 6         88.0         98.0         86.0          NaN          NaN       Yes

# %% [markdown]
# #### Rechecking null values:

# %%
#Sum nulls for each column
call.isnull().sum()
# Out:
# Employee        0
# Queue           0
# Q1 - Call 1    38
# Q1 - Call 2    38
# Q2 - Call 1    41
# Q2 - Call 2    42
# Q3 - Call 1    41
# Q3 - Call 2    41
# Q4 - Call 1    67
# Q4 - Call 2    67
# Scheduled      37
# dtype: int64

# %% [markdown]
# #### Adding a column for average score:

# %%
# Define the columns containing call scores
call_score_columns = call.columns[3:10]

#Add Avg Score column that is the average of all non null values
call['Avg Score'] = call[call_score_columns].mean(axis=1, skipna=True)

print(call.head())
# Out:
#            Employee      Queue  Q1 - Call 1  Q1 - Call 2  Q2 - Call 1  \
# 2     Casey Leblanc  Technical         96.0         96.0         96.0
# 3  Robert Hernandez  Technical         98.0         96.0         96.0
# 4    Shelley Acosta  Technical        100.0         94.0        100.0
# 5       Joel Powers  Technical          NaN          NaN          NaN
# 6   Margaret Hughes  Technical          NaN          NaN         94.0
#
#    Q2 - Call 2  Q3 - Call 1  Q3 - Call 2  Q4 - Call 1  Q4 - Call 2 Scheduled  \
# 2        100.0          NaN          NaN          NaN          NaN       NaN
# 3         98.0        100.0        100.0          NaN          NaN       NaN
# 4        100.0          NaN          NaN          NaN          NaN       NaN
# 5          NaN         92.0         96.0          NaN          NaN       NaN
# 6         88.0         98.0         86.0          NaN          NaN       Yes
#
#    Avg Score
# 2  97.333333
# 3  98.000000
# 4  98.000000
# 5  94.000000
# 6  91.500000

# %% [markdown]
# ## **Cleaning up Quality of New Hire CSV:**

# %% [markdown]
# #### First need to randomize the names:

# %%
file_path2 = r"QNH_11_17_23.csv"

# Read the CSV file into a DataFrame
qnh = pd.read_csv(file_path2)

# Randomize the names in the first column
fake = Faker()
qnh['Employee'] = [fake.name() for _ in range(len(qnh))]


# Display the DataFrame
print(qnh.head())
# Out:
#          Employee Gender               Coach  ActiveStartDate  \
# 0   Heidi Randall      F       Sabrina Clore       10/12/2009
# 1  Jesse Marshall      F                 LCS        1/23/2012
# 2    David Strong      M        Don Paquette        7/11/2016
# 3    Jordan Davis      F     Human Resources         1/3/2017
# 4     Tina Jordan      F  Account Management        8/18/2014
#
#         Department  QNH Foundations Coach Survey  \
# 0  Product Support                          80.0
# 1              PDC                          88.0
# 2  Product Support                           NaN
# 3               HR                           NaN
# 4              LCS                           NaN
#
#    CORE Certification First Result  QNH 45 Day Employee Survey  \
# 0                             95.0                        59.0
# 1                             50.0                       100.0
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
#
#    QNH 45 Day Coach Survey  QNH 90 Day Employee Survey  \
# 0                     82.0                        57.0
# 1                     90.0                        99.0
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
#
#    QNH 90 Day Lead Survey  QNH 180 Day Employee Survey  \
# 0                    70.0                         76.0
# 1                   100.0                        100.0
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#    QNH 180 Day Lead Survey  QNH 270 Day Employee Survey  \
# 0                     80.0                         76.0
# 1                      0.0                         99.0
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
#
#    QNH 270 Day Lead Survey  QNH Termination Date of Termination
# 0                     72.0              NaN                 NaN
# 1                    100.0              NaN                 NaN
# 2                      NaN              NaN                 NaN
# 3                      NaN              NaN           8/20/2021
# 4                      NaN              NaN           2/19/2021

# %% [markdown]
# #### Convert all scores to integers:

# %%
qnh['QNH Foundations Coach Survey'] = pd.to_numeric(qnh['QNH Foundations Coach Survey'], errors='coerce').astype('Int64')
qnh['CORE Certification First Result'] = pd.to_numeric(qnh['CORE Certification First Result'], errors='coerce').astype('Int64')
qnh['QNH 45 Day Employee Survey'] = pd.to_numeric(qnh['QNH 45 Day Employee Survey'], errors='coerce').astype('Int64')
qnh['QNH 45 Day Coach Survey'] = pd.to_numeric(qnh['QNH 45 Day Coach Survey'], errors='coerce').astype('Int64')
qnh['QNH 90 Day Employee Survey'] = pd.to_numeric(qnh['QNH 90 Day Employee Survey'], errors='coerce').astype('Int64')
qnh['QNH 90 Day Lead Survey'] = pd.to_numeric(qnh['QNH 90 Day Lead Survey'], errors='coerce').astype('Int64')
qnh['QNH 180 Day Employee Survey'] = pd.to_numeric(qnh['QNH 180 Day Employee Survey'], errors='coerce').astype('Int64')
qnh['QNH 180 Day Lead Survey'] = pd.to_numeric(qnh['QNH 180 Day Lead Survey'], errors='coerce').astype('Int64')
qnh['QNH 270 Day Employee Survey'] = pd.to_numeric(qnh['QNH 270 Day Employee Survey'], errors='coerce').astype('Int64')
qnh['QNH 270 Day Lead Survey'] = pd.to_numeric(qnh['QNH 270 Day Lead Survey'], errors='coerce').astype('Int64')


print(qnh.head())
# Out:
#          Employee Gender               Coach  ActiveStartDate  \
# 0   Heidi Randall      F       Sabrina Clore       10/12/2009
# 1  Jesse Marshall      F                 LCS        1/23/2012
# 2    David Strong      M        Don Paquette        7/11/2016
# 3    Jordan Davis      F     Human Resources         1/3/2017
# 4     Tina Jordan      F  Account Management        8/18/2014
#
#         Department  QNH Foundations Coach Survey  \
# 0  Product Support                            80
# 1              PDC                            88
# 2  Product Support                          <NA>
# 3               HR                          <NA>
# 4              LCS                          <NA>
#
#    CORE Certification First Result  QNH 45 Day Employee Survey  \
# 0                               95                          59
# 1                               50                         100
# 2                             <NA>                        <NA>
# 3                             <NA>                        <NA>
# 4                             <NA>                        <NA>
#
#    QNH 45 Day Coach Survey  QNH 90 Day Employee Survey  \
# 0                       82                          57
# 1                       90                          99
# 2                     <NA>                        <NA>
# 3                     <NA>                        <NA>
# 4                     <NA>                        <NA>
#
#    QNH 90 Day Lead Survey  QNH 180 Day Employee Survey  \
# 0                      70                           76
# 1                     100                          100
# 2                    <NA>                         <NA>
# 3                    <NA>                         <NA>
# 4                    <NA>                         <NA>
#
#    QNH 180 Day Lead Survey  QNH 270 Day Employee Survey  \
# 0                       80                           76
# 1                        0                           99
# 2                     <NA>                         <NA>
# 3                     <NA>                         <NA>
# 4                     <NA>                         <NA>
#
#    QNH 270 Day Lead Survey  QNH Termination Date of Termination
# 0                       72              NaN                 NaN
# 1                      100              NaN                 NaN
# 2                     <NA>              NaN                 NaN
# 3                     <NA>              NaN           8/20/2021
# 4                     <NA>              NaN           2/19/2021

# %% [markdown]
# #### Adding a new column to calculate Quality of New Hire Score:

# %%
# Define the columns containing qnh scores
qnh_score_columns = qnh.columns[5:15]

#Add QNH Score column that is the average of all non null values
qnh['QNH Score'] = qnh[qnh_score_columns].mean(axis=1, skipna=True)

print(qnh.head())
# Out:
#          Employee Gender               Coach  ActiveStartDate  \
# 0   Heidi Randall      F       Sabrina Clore       10/12/2009
# 1  Jesse Marshall      F                 LCS        1/23/2012
# 2    David Strong      M        Don Paquette        7/11/2016
# 3    Jordan Davis      F     Human Resources         1/3/2017
# 4     Tina Jordan      F  Account Management        8/18/2014
#
#         Department  QNH Foundations Coach Survey  \
# 0  Product Support                            80
# 1              PDC                            88
# 2  Product Support                          <NA>
# 3               HR                          <NA>
# 4              LCS                          <NA>
#
#    CORE Certification First Result  QNH 45 Day Employee Survey  \
# 0                               95                          59
# 1                               50                         100
# 2                             <NA>                        <NA>
# 3                             <NA>                        <NA>
# 4                             <NA>                        <NA>
#
#    QNH 45 Day Coach Survey  QNH 90 Day Employee Survey  \
# 0                       82                          57
# 1                       90                          99
# 2                     <NA>                        <NA>
# 3                     <NA>                        <NA>
# 4                     <NA>                        <NA>
#
#    QNH 90 Day Lead Survey  QNH 180 Day Employee Survey  \
# 0                      70                           76
# 1                     100                          100
# 2                    <NA>                         <NA>
# 3                    <NA>                         <NA>
# 4                    <NA>                         <NA>
#
#    QNH 180 Day Lead Survey  QNH 270 Day Employee Survey  \
# 0                       80                           76
# 1                        0                           99
# 2                     <NA>                         <NA>
# 3                     <NA>                         <NA>
# 4                     <NA>                         <NA>
#
#    QNH 270 Day Lead Survey  QNH Termination Date of Termination QNH Score
# 0                       72              NaN                 NaN      74.7
# 1                      100              NaN                 NaN      82.6
# 2                     <NA>              NaN                 NaN      <NA>
# 3                     <NA>              NaN           8/20/2021      <NA>
# 4                     <NA>              NaN           2/19/2021      <NA>

# %% [markdown]
# #### Adding an additional "Outcome" column based on QNH Score:

# %%
qnh_scores = qnh['QNH Score']

# Add a new column 'Outcome' based on the QNH scores
qnh['Outcome'] = np.where(qnh_scores > 79, 'Met QNH', np.where(qnh_scores.notna(), 'Not Met QNH', '<NA>'))

# Display the updated DataFrame
print(qnh.head())
# Out:
#          Employee Gender               Coach  ActiveStartDate  \
# 0   Heidi Randall      F       Sabrina Clore       10/12/2009
# 1  Jesse Marshall      F                 LCS        1/23/2012
# 2    David Strong      M        Don Paquette        7/11/2016
# 3    Jordan Davis      F     Human Resources         1/3/2017
# 4     Tina Jordan      F  Account Management        8/18/2014
#
#         Department  QNH Foundations Coach Survey  \
# 0  Product Support                            80
# 1              PDC                            88
# 2  Product Support                          <NA>
# 3               HR                          <NA>
# 4              LCS                          <NA>
#
#    CORE Certification First Result  QNH 45 Day Employee Survey  \
# 0                               95                          59
# 1                               50                         100
# 2                             <NA>                        <NA>
# 3                             <NA>                        <NA>
# 4                             <NA>                        <NA>
#
#    QNH 45 Day Coach Survey  QNH 90 Day Employee Survey  \
# 0                       82                          57
# 1                       90                          99
# 2                     <NA>                        <NA>
# 3                     <NA>                        <NA>
# 4                     <NA>                        <NA>
#
#    QNH 90 Day Lead Survey  QNH 180 Day Employee Survey  \
# 0                      70                           76
# 1                     100                          100
# 2                    <NA>                         <NA>
# 3                    <NA>                         <NA>
# 4                    <NA>                         <NA>
#
#    QNH 180 Day Lead Survey  QNH 270 Day Employee Survey  \
# 0                       80                           76
# 1                        0                           99
# 2                     <NA>                         <NA>
# 3                     <NA>                         <NA>
# 4                     <NA>                         <NA>
#
#    QNH 270 Day Lead Survey  QNH Termination Date of Termination QNH Score  \
# 0                       72              NaN                 NaN      74.7
# 1                      100              NaN                 NaN      82.6
# 2                     <NA>              NaN                 NaN      <NA>
# 3                     <NA>              NaN           8/20/2021      <NA>
# 4                     <NA>              NaN           2/19/2021      <NA>
#
#        Outcome
# 0  Not Met QNH
# 1      Met QNH
# 2         <NA>
# 3         <NA>
# 4         <NA>

# %% [markdown]
# #### Dropping null outcomes

# %%
#Dropping rows that have null outcome
qnh = qnh.drop(qnh[qnh['Outcome'] == '<NA>'].index)
print(qnh.head())
# Out:
#           Employee Gender          Coach  ActiveStartDate        Department  \
# 0    Heidi Randall      F  Sabrina Clore       2009-10-12   Product Support
# 1   Jesse Marshall      F            LCS       2012-01-23               PDC
# 49    Tracy Cooper      F  Morgan Walker       2019-11-11  Customer Success
# 53  Melissa Taylor      M   Don Paquette       2019-01-07    Implementation
# 60    Daniel Green      M            LCS       2020-02-03               PDC
#
#     QNH Foundations Coach Survey  CORE Certification First Result  \
# 0                             80                               95
# 1                             88                               50
# 49                          <NA>                               87
# 53                          <NA>                               97
# 60                          <NA>                               98
#
#     QNH 45 Day Employee Survey  QNH 45 Day Coach Survey  \
# 0                           59                       82
# 1                          100                       90
# 49                        <NA>                     <NA>
# 53                        <NA>                     <NA>
# 60                        <NA>                     <NA>
#
#     QNH 90 Day Employee Survey  QNH 90 Day Lead Survey  \
# 0                           57                      70
# 1                           99                     100
# 49                        <NA>                    <NA>
# 53                        <NA>                    <NA>
# 60                        <NA>                    <NA>
#
#     QNH 180 Day Employee Survey  QNH 180 Day Lead Survey  \
# 0                            76                       80
# 1                           100                        0
# 49                         <NA>                     <NA>
# 53                         <NA>                     <NA>
# 60                         <NA>                     <NA>
#
#     QNH 270 Day Employee Survey  QNH 270 Day Lead Survey  QNH Termination  \
# 0                            76                       72              NaN
# 1                            99                      100              NaN
# 49                         <NA>                     <NA>              NaN
# 53                         <NA>                     <NA>              NaN
# 60                         <NA>                     <NA>              NaN
#
#    Date of Termination QNH Score      Outcome  Length of Service
# 0                  NaT      74.7  Not Met QNH              14.08
# 1                  NaT      82.6      Met QNH              11.83
# 49                 NaT      87.0      Met QNH               4.00
# 53                 NaT      97.0      Met QNH               4.83
# 60                 NaT      98.0      Met QNH               3.75

# %% [markdown]
# #### Calculating length of service and addding as column:

# %%
import datetime as dt

# Convert date columns to datetime objects
qnh[' ActiveStartDate'] = pd.to_datetime(qnh[' ActiveStartDate'])
qnh['Date of Termination'] = pd.to_datetime(qnh['Date of Termination'])

# Calculate length of service in years
qnh['Length of Service'] = ((qnh['Date of Termination'].dt.year - qnh[' ActiveStartDate'].dt.year) + \
                           ((qnh['Date of Termination'].dt.month - qnh[' ActiveStartDate'].dt.month) / 12)).round(2)

# If 'Date of Termination' is null, calculate the length of service until today's date
today = dt.datetime.today()

qnh['Length of Service'].fillna(((today.year - qnh[' ActiveStartDate'].dt.year) +
                               ((today.month - qnh[' ActiveStartDate'].dt.month) / 12)).round(2), inplace=True)


# Display the updated new column
print(qnh['Length of Service'].head())
# Out:
# 0     14.08
# 1     11.83
# 49     4.00
# 53     4.83
# 60     3.75
# Name: Length of Service, dtype: float64

# %% [markdown]
# ## **Merging the three dataframes together**

# %%
# Merge dataframes
result = pd.merge(cert, call, on='Employee', how='outer')
result = pd.merge(result, qnh, on='Employee', how='outer')

# Display the merged dataframe
print(result)
# Out:
#                 Employee                     Assessment  Score Date Completed  \
# 0     Vincent Montgomery  Core Certification Assessment   87.0     10/20/2023
# 1             Kelly Hart  Core Certification Assessment   59.0     10/19/2023
# 2           Brian Murray  Core Certification Assessment  100.0     10/17/2023
# 3     Michelle Carpenter  Core Certification Assessment   84.0     10/13/2023
# 4           Chad Jenkins  Core Certification Assessment   91.0     10/13/2023
# ...                  ...                            ...    ...            ...
# 1108       Crystal Irwin                            NaN    NaN            NaN
# 1109        Ashley Boyer                            NaN    NaN            NaN
# 1110         Perry Moore                            NaN    NaN            NaN
# 1111         Stacy Davis                            NaN    NaN            NaN
# 1112        Darren Gibbs                            NaN    NaN            NaN
#
#      Product Pass/Fail  Sum Queue  Q1 - Call 1  Q1 - Call 2  ...  \
# 0       RM12      Pass  1.0   NaN          NaN          NaN  ...
# 1       RM12      Fail  0.0   NaN          NaN          NaN  ...
# 2       RM12      Pass  1.0   NaN          NaN          NaN  ...
# 3       RM12      Pass  1.0   NaN          NaN          NaN  ...
# 4       RM12      Pass  1.0   NaN          NaN          NaN  ...
# ...      ...       ...  ...   ...          ...          ...  ...
# 1108     NaN       NaN  NaN   NaN          NaN          NaN  ...
# 1109     NaN       NaN  NaN   NaN          NaN          NaN  ...
# 1110     NaN       NaN  NaN   NaN          NaN          NaN  ...
# 1111     NaN       NaN  NaN   NaN          NaN          NaN  ...
# 1112     NaN       NaN  NaN   NaN          NaN          NaN  ...
#
#       QNH 90 Day Lead Survey  QNH 180 Day Employee Survey  \
# 0                       <NA>                         <NA>
# 1                       <NA>                         <NA>
# 2                       <NA>                         <NA>
# 3                       <NA>                         <NA>
# 4                       <NA>                         <NA>
# ...                      ...                          ...
# 1108                    <NA>                         <NA>
# 1109                    <NA>                         <NA>
# 1110                    <NA>                         <NA>
# 1111                    <NA>                         <NA>
# 1112                    <NA>                         <NA>
#
#       QNH 180 Day Lead Survey  QNH 270 Day Employee Survey  \
# 0                        <NA>                         <NA>
# 1                        <NA>                         <NA>
# 2                        <NA>                         <NA>
# 3                        <NA>                         <NA>
# 4                        <NA>                         <NA>
# ...                       ...                          ...
# 1108                     <NA>                         <NA>
# 1109                     <NA>                         <NA>
# 1110                     <NA>                         <NA>
# 1111                     <NA>                         <NA>
# 1112                     <NA>                         <NA>
#
#       QNH 270 Day Lead Survey  QNH Termination Date of Termination  QNH Score  \
# 0                        <NA>              NaN                 NaT        NaN
# 1                        <NA>              NaN                 NaT        NaN
# 2                        <NA>              NaN                 NaT        NaN
# 3                        <NA>              NaN                 NaT        NaN
# 4                        <NA>              NaN                 NaT        NaN
# ...                       ...              ...                 ...        ...
# 1108                     <NA>              NaN                 NaT       99.5
# 1109                     <NA>              NaN                 NaT       84.5
# 1110                     <NA>              NaN                 NaT       95.0
# 1111                     <NA>              NaN                 NaT       88.5
# 1112                     <NA>              NaN                 NaT       96.0
#
#       Outcome Length of Service
# 0         NaN               NaN
# 1         NaN               NaN
# 2         NaN               NaN
# 3         NaN               NaN
# 4         NaN               NaN
# ...       ...               ...
# 1108  Met QNH              0.08
# 1109  Met QNH              0.08
# 1110  Met QNH              0.08
# 1111  Met QNH              0.08
# 1112  Met QNH              0.00
#
# [1113 rows x 37 columns]

# %% [markdown]
# ## **Saving merged files to csv file for use in Tableau**

# %%
# Save the DataFrame to a new CSV file
output_file_path = 'hr_data.csv'
result.to_csv(output_file_path, index=False)

# %% [markdown]
# # **Some visualizations with python:**

# %% [markdown]
# ## **Certification Visualizations:**

# %% [markdown]
# #### Creating pivot table to display amount of certifications passed by Assessment. This will allow us to forecast how many pins we need to order per assessment for next year.

# %%
pivot = cert.pivot_table(index =['Assessment'], 
                       values =['Sum'], 
                       aggfunc ='sum') 
print(pivot)
# Out:
#                                           Sum
# Assessment
# Bookkeeping Certification                  96
# Core Certification Assessment             135
# FBM Certification Assessment               52
# Owners and Finance Queue                   40
# RM Certification: General Knowledge        84
# RM Certification: Integrations Knowledge   51
# RM Certification: Mobile Knowledge         60
# RM Certification: Technical Knowledge      80
# Scripting Certification Assessment         23

# %% [markdown]
# #### Checking the distribution of certification scores among employees. This helps us to get an overall look at how employees are scoring on certifications.

# %%
plt.rcParams['figure.figsize'] = (15, 7)
sns.displot(cert['Score'], color = 'orange')
plt.title('Distribution of Certification Score among the Employees', fontsize = 15)
plt.xlabel('Score', fontsize = 10)
plt.ylabel('Sum', fontsize = 10)
plt.show()

# %% [markdown]
# #### Visualizing overall Pass vs Fail.

# %%
#Switching the true false output from boolean to strings for Pass or Fail labels
cert['Pass/Fail'] = cert['Pass/Fail'].replace({True: 'Pass', False: 'Fail'})
print(cert['Pass/Fail'].head())
# Out:
# 0    Pass
# 1    Fail
# 2    Pass
# 3    Pass
# 4    Pass
# Name: Pass/Fail, dtype: object

# %%
#counting pass vs fail certifications
cert['Pass/Fail'].value_counts()
# Out:
# Pass/Fail
# Pass    621
# Fail    128
# Name: count, dtype: int64

# %%
# plotting a donut chart for visualizing pass/fail

size = [621, 128]
colors = ['orange', 'blue']
labels = "Pass", "Fail"

my_circle = plt.Circle((0, 0), 0.7, color = 'white')

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Percentage of Pass vs Fail', fontsize = 20)
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()

# %% [markdown]
# #### Displaying scores per assessment:

# %%
# set theme for plots
sns.set_theme(font_scale=1.2) 

# Create scatter plot
plt.figure(figsize=(14, 5))
sns.scatterplot(data=cert,
                x="Score",
                y="Assessment",
                hue="Pass/Fail"
               )

plt.title("Score distribution by Assessment")
plt.show()

# %% [markdown]
# #### Showing pass rate by call queue only assessments in bar graph. If the majority are passes, the queue training does a significant job of preparing emplyee for certification. If it is split, the training should be adjusted. If the majority fail, the assessment should be adjusted.

# %%
# Select only queue certifications
unique_assessments = cert['Assessment'].unique()[1:9]  

# Set up a 4x2 grid of subplots
fig, axes = plt.subplots(4, 2, figsize=(15, 15))

# Flatten the 4x2 array of subplots to simplify indexing
axes = axes.flatten()

for i, assessment in enumerate(unique_assessments):
    # Filter for the current assessment
    subset_df = cert[cert['Assessment'] == assessment]
    
    # Create a count plot for pass/fail for the current assessment
    sns.countplot(x='Pass/Fail', data=subset_df, ax=axes[i])
    
    # Set title for each subplot
    axes[i].set_title(f'Assessment: {assessment}')
    
    # Set labels
    axes[i].set_xlabel('Passed Assessment')
    axes[i].set_ylabel('Count')

# Adjust layout for better readability
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# #### Visualizing pass rate for all certifications. This will help to determine the difficulty of the certifications and if more training needs to be created for any certification.

# %%
# Select all certifications
all_assessments = cert['Assessment'].unique()[:10]  

# Set up a 3x3 grid of subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

# Flatten the 3x3 array of subplots to simplify indexing
axes = axes.flatten()

for i, assessment in enumerate(all_assessments):
    # Filter the DataFrame for the current assessment
    subset_df = cert[cert['Assessment'] == assessment]
    
    # Count the number of pass and fail occurrences
    pass_fail_counts = subset_df['Pass/Fail'].value_counts()
    
    # Create a pie chart for pass rate for the current assessment
    axes[i].pie(pass_fail_counts, labels=pass_fail_counts.index, autopct='%1.1f%%', startangle=90)
    
    # Set title for each subplot
    axes[i].set_title(f'{assessment}')

# Adjust layout for better readability
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# ## **Call Coaching Visualizations:**

# %% [markdown]
# #### Pulling in the list of upcoming call coachings and adding a checkbox next to each of them:
# <p>This should show as a pop up display so we can check off evaluations as they are completed</p>

# %%
from tkinter import IntVar

names = call['Employee'].tolist()  

# Create a tkinter window
window = tk.Tk()
window.title("Names with Checkboxes")

# Create IntVar list to hold the checkbox states
checkbox_vars = [IntVar() for _ in names]

# Create and display checkboxes
for i, name in enumerate(names):
    checkbox = tk.Checkbutton(window, text=name, variable=checkbox_vars[i])
    checkbox.pack(anchor='w')

window.mainloop()

# %% [markdown]
# #### Call Coaching scores by queue. This will show us employee customer service success by queue and may help to identify lapses in call preparation.

# %%
# Create a scatter plot of Avg Score by Queue
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Queue', y='Avg Score', data=call)

# Set labels and title
plt.xlabel('Queue')
plt.ylabel('Average Score')
plt.title('Scatter Plot of Avg Score by Queue')

# Display the plot
plt.show()

# %% [markdown]
# ## **Quality of New Hire Visualizations:**

# %% [markdown]
# ##### Word Art displaying most popular departments. This helps to identify recruitment trends

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopword = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopword).generate(str(qnh['Department']))

plt.rcParams['figure.figsize'] = (10, 8)
print(wordcloud)
plt.imshow(wordcloud)
plt.title('Most Popular Departments', fontsize = 10)
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000002A84AE43790>

# %% [markdown]
# #### Displaying length of service among employees. This helps to identify tenure as well as

# %%
# displaying the distribution of length of service

sns.displot(qnh['Length of Service'], color = 'blue')
plt.title('Distribution of length of service among the Employees', fontsize = 20)
plt.xlabel('Length of Service in years', fontsize = 10)
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# #### Visualizing employees per Professional Development Coach. This helps to ensure resources are being appropriately divided and can indicate need for an additional coach.

# %%
# Output number of employees per coach
pivot = qnh.pivot_table(index =['Coach'], 
                       values =['Employee'], 
                       aggfunc ='count') 
print(pivot)
# Out:
#                        Employee
# Coach
# Account Management            2
# Carrie Legner                18
# Don Paquette                199
# Human Resources               1
# IT Services                   2
# Internal Applications         1
# Jennifer Kephart            215
# LCS                          82
# Morgan Walker               218
# Nick Geisen                  14
# Sabrina Clore                51

# %%
# plotting a donut chart for visualizing only HR coaches employee share

size = [218, 215, 199,51]
colors = ['skyblue', 'orange', 'blue','darkorange']
labels = "Morgan", "Jen", "Don", "Sabrina"

my_circle = plt.Circle((0, 0), 0.7, color = 'white')

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Showing share of employees by coach', fontsize = 20)
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()

# %% [markdown]
# #### Displaying the gender gap in the current employee count:

# %%
#creating picot table to output count
pivot = qnh.pivot_table(index =['Gender'], 
                       values =['Employee'], 
                       aggfunc ='count') 
print(pivot)
# Out:
#         Employee
# Gender
# F            326
# M            476
# N              1

# %%
# plotting a pie chart

size = [476, 326]
labels = "Male", "Female"
colors = ['orange', 'blue']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing Gender Gap', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# #### Finally, graphs to display Quality of New hire statistics:

# %%
#count values of Met QNH and Not Met QNH
qnh['Outcome'].value_counts()
# Out:
# Outcome
# No Value       503
# Met QNH        251
# Not Met QNH     49
# Name: count, dtype: int64

# %% [markdown]
# #### The following pie chart displays the percentage of our employees who have not met the minimum quality of new hire requirements. The quality of new hire measure forecasts likelihood of turnover. This chart tells us to prepare for a possible 17% turnover rate

# %%
# plotting a pie chart
size = [49, 251]
labels = "Not Met QNH > 80", "Met QNH > 80"
colors = ['blue', 'orange']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing Gap in Employees in terms of QNH', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %% [markdown]
# #### The following graph displays our employee population and their overall quality within 10 point ranges. We can look more closely at the >99 range for possible promotions.

# %%
#Creating display for distribution of scores by range
qnh_scores_all = qnh['QNH Score']

# Filter out null or NA values
qnh_scores_all = qnh_scores_all.dropna()

# Define score ranges
score_ranges = [0, 59, 69, 79, 89, 99, float('inf')]
range_labels = ['<59', '60-69', '70-79', '80-89', '90-99', '>99']

# Categorize scores into ranges
qnh_score_bins = pd.cut(qnh_scores_all, bins=score_ranges, labels=range_labels, right=False)

# Create a bar plot
plt.figure(figsize=(10, 6))
qnh_score_bins.value_counts().sort_index().plot(kind='bar', color='orange')

# Set labels and title
plt.xlabel('QNH Score Ranges')
plt.ylabel('Count of Employees')
plt.title('Distribution of QNH Scores')

# Display the plot
plt.show()

# %% [markdown]
# #### Display what factor certification scores play in Quality of New Hire

# %%
# scatter plot between average certification score and quality of new hire score

data = pd.crosstab(result['Score'], result['Outcome'])
data.div(data.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 9), color = ['orange', 'blue'])

plt.title('Looking at the Dependency of Certification Score in Quality of New Hire', fontsize = 30)
plt.xlabel('Average Certification Scores', fontsize = 15)
plt.legend()
plt.show()

# %% [markdown]
# #### Display what factor call coaching scores play in Quality of New Hire

# %%
result['Avg Score'] = pd.to_numeric(result['Avg Score'])

# %%
# scatter plot between average call coaching score and quality of new hire score

data = pd.crosstab(result['Avg Score'], result['Outcome'])
data.div(data.sum(1).astype(int), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 9), color = ['orange', 'blue'])

plt.title('Looking at the Dependency of Call Coaching Score in Quality of New Hire', fontsize = 30)
plt.xlabel('Average Call Coaching Scores', fontsize = 15)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 4
#       1 # scatter plot between average call coaching score and quality of new hire score
#       3 data = pd.crosstab(result['Avg Score'], result['Outcome'])
# ----> 4 data.div(data.sum(1).astype(int), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 9), color = ['orange', 'blue'])
#       6 plt.title('Looking at the Dependency of Call Coaching Score in Quality of New Hire', fontsize = 30)
#       7 plt.xlabel('Average Call Coaching Scores', fontsize = 15)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_matplotlib\core.py:446, in MPLPlot.generate(self)
#     444 def generate(self) -> None:
#     445     self._args_adjust()
# --> 446     self._compute_plot_data()
#     447     self._setup_subplots()
#     448     self._make_plot()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\plotting\_matplotlib\core.py:632, in MPLPlot._compute_plot_data(self)
#     630 # no non-numeric frames or series allowed
#     631 if is_empty:
# --> 632     raise TypeError("no numeric data to plot")
#     634 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
#Dropping rows that have null outcome
qnh_non_null = result.drop(result[result['Outcome'] == '<NA>'].index)
print(qnh_non_null())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 3
#       1 #Dropping rows that have null outcome
#       2 qnh_non_null = result.drop(result[result['Outcome'] == '<NA>'].index)
# ----> 3 print(qnh_non_null())
#
# TypeError: 'DataFrame' object is not callable

# %%
# checking dependency of gender over promotion

data = pd.crosstab(result['Gender'], result['Outcome'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (7, 5), color = ['blue', 'orange'])

plt.title('Dependency of Genders in determining Promotion of Employees', fontsize = 30)
plt.xlabel('Gender', fontsize = 20)
plt.legend()
plt.show()
