# %% [markdown]
# # *The purpose of this overview is to provide a snapshot view of data produced in the final results csv*

# %% [markdown]
# ## **Pulling in all needed dbs**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"hr_data.csv"

# Read the CSV file into a DataFrame
result = pd.read_csv(file_path)

# %% [markdown]
# #### Display what factor certification scores play in Quality of New Hire

# %%
# scatter plot between average certification score and quality of new hire score

data = pd.crosstab(result['Score'], result['Outcome'])
data.div(data.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 9), color = ['orange', 'blue'])

plt.title('Looking at the Dependency of Certification Score in Quality of New Hire', fontsize = 30)
plt.xlabel('Certification Scores', fontsize = 15)
plt.legend()
plt.show()

# %% [markdown]
# #### Display what factor genders play in Quality of New Hire

# %%
# checking dependency of gender over quality of new hire score

data = pd.crosstab(result['Gender'], result['Outcome'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (8, 6), color = ['blue', 'orange'])

plt.title('Dependency of Genders in determining QNH of Employees', fontsize = 30)
plt.xlabel('Gender', fontsize = 20)
plt.legend()
plt.show()

# %% [markdown]
# #### Showcasing correlation between call coaching score and certification score by queue.

# %%
# Create a scatter plot for correlation between 'Avg Score' and certification score
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Score', y='Avg Score', hue='Queue', data=result, palette='viridis')

# Set labels and title
plt.xlabel('Certification Score')
plt.ylabel('Call Coaching Average')
plt.title('Call Coaching Score vs Certification Score')

# Display the legend
plt.legend(title='Queue', loc='lower left')

# Display the plot
plt.show()

# %% [markdown]
# #### Showing correlation between Assessment Score, Call Coaching Average Score, Quality of New Hire Score, and Length of Service

# %%
#Dropping all but avg scores (qnh, call, and assessment)
result = result.drop(result.columns[[0,1,3,4,5,6,7,8,10,11,12,13,15]], axis=1)
print(result.head())
# Out:
#    Score  Avg Score  QNH Score  Length of Service
# 0     87        NaN       74.7              14.08
# 1     59        NaN       82.6              11.83
# 2    100  97.333333        NaN                NaN
# 3     84  98.000000        NaN                NaN
# 4     91  98.000000        NaN                NaN

# %%
correlation = result. corr ()  
correlation. style. background_gradient (cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_47fe6_row0_col0, #T_47fe6_row1_col1, #T_47fe6_row2_col2, #T_47fe6_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_47fe6_row0_col1, #T_47fe6_row2_col3, #T_47fe6_row3_col0, #T_47fe6_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_47fe6_row0_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_47fe6_row0_col3 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_47fe6_row1_col0 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_47fe6_row1_col2, #T_47fe6_row1_col3, #T_47fe6_row2_col1, #T_47fe6_row3_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_47fe6_row2_col0 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# </style>
# <table id="T_47fe6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47fe6_level0_col0" class="col_heading level0 col0" >Score</th>
#       <th id="T_47fe6_level0_col1" class="col_heading level0 col1" >Avg Score</th>
#       <th id="T_47fe6_level0_col2" class="col_heading level0 col2" >QNH Score</th>
#       <th id="T_47fe6_level0_col3" class="col_heading level0 col3" >Length of Service</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47fe6_level0_row0" class="row_heading level0 row0" >Score</th>
#       <td id="T_47fe6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_47fe6_row0_col1" class="data row0 col1" >0.009563</td>
#       <td id="T_47fe6_row0_col2" class="data row0 col2" >0.031666</td>
#       <td id="T_47fe6_row0_col3" class="data row0 col3" >-0.224447</td>
#     </tr>
#     <tr>
#       <th id="T_47fe6_level0_row1" class="row_heading level0 row1" >Avg Score</th>
#       <td id="T_47fe6_row1_col0" class="data row1 col0" >0.009563</td>
#       <td id="T_47fe6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_47fe6_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_47fe6_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_47fe6_level0_row2" class="row_heading level0 row2" >QNH Score</th>
#       <td id="T_47fe6_row2_col0" class="data row2 col0" >0.031666</td>
#       <td id="T_47fe6_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_47fe6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_47fe6_row2_col3" class="data row2 col3" >-0.334659</td>
#     </tr>
#     <tr>
#       <th id="T_47fe6_level0_row3" class="row_heading level0 row3" >Length of Service</th>
#       <td id="T_47fe6_row3_col0" class="data row3 col0" >-0.224447</td>
#       <td id="T_47fe6_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_47fe6_row3_col2" class="data row3 col2" >-0.334659</td>
#       <td id="T_47fe6_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
